# %% [markdown]
# # Yaml --> Pygal ... Yamgal
#
# The ultimate goal for this is to emulate the GitHub Shield's functionality
# but for simple charts.
#
# # Usage
#
# `![demo](https://yamgal-server-c6l3dwv2sq-de.a.run.app/TYPE/DATA/OPTIONAL_CONFIG)`
#
# Where:
#   - **TYPE**: `line | bar | pie | donut | stackedbar | stackedline | xy | histogram | dot` Case insensitive
#   - **DATA**: Key:Value pairs separated by ';'. No spaces.
#   ie: `one:[1,2,3];two:[5,6,7]` or some charts, like histogram take lists of lists charts `one:[[<height>,<x_start>,<x_end>],[...]]` see [Pyagl docs](http://www.pygal.org/en/stable/documentation/types/histogram.html)
#   - **OPTIONAL_CONFIG**: Also Key:Value pairs. All options availiable to Pygal charts are availaible. Including by not limited to:
#     - `title` (str): No spaces. Case is preserved) Default=None
#     - `width` (int): Default=pretty big
#     - `height` (int): Default=pretty big
#     - `stroke` (True | False): Wether to draw a line between points. Default=True
#     - `dots` (True | False): Wether to draw points. Default=True
#     - `dot_size` (int): Default=2...ish
#     - `fill` (True | False): Fill below the line down to zero. Default=False
#     - `zero` (float): set reference to fill down to. Default=0
#     - `x_title` (str): No spaces. Case is preserved) Default=None
#     - `y_title` (str): No spaces. Case is preserved) Default=None
#     - `x_label_rotation` (float):  0 is horazontal, - is cw, + ccw. Default=0
#     - `y_label_rotation` (float):  0 is horazontal, - is cw, + ccw. Default=0
#     - `interpolate` (`cubic` | `quadratic` | `lagrange` | `trigonometric` | `hermite`) Default=`linear`
#     - `style` (`blue` | `clean` | `dark_colorized` | `dark_green_blue` | `dark_green` | `dark_solarized` | `dark` | `default` | `light_colorized` | `light_green` | `light_solarized` | `light` | `neon` | `red_blue` | `turquoise`)

# %% [markdown]
# ## Simple Line Chart
#
# First there is no configuration. Just a simple bare bones example to get started.
#
# **Note**:
#
#   - Each series in the data is a `key:value` pair separated a `;`
#   - Think of the `;` as a _new line_ and the data is kind of like an _inline_ yaml definition. (Spoiler alert! Under the hood, converting to yaml is pretty much all this does :-p)
#
#
# `![demo](https://yamgal-server-c6l3dwv2sq-de.a.run.app/line/one:[1,2,3];two:[5,6,7])`
#
# ![demo](https://yamgal-server-c6l3dwv2sq-de.a.run.app/line/one:[1,2,3];two:[5,6,7])

# %% [markdown]
# ## Use html tags, allows you to resize
#
# `<img src="https://yamgal-server-c6l3dwv2sq-de.a.run.app/line/one:[1,2,3];two:[5,6,7]" alt="demo" width="300" height="200">`
#
# <img src="https://yamgal-server-c6l3dwv2sq-de.a.run.app/line/one:[1,2,3];two:[5,6,7]" alt="demo" width="300" height="200">

# %% [markdown]
# ## Adding Some Basic Config
#
# To be honest all the config is basic, it's just knowing words to use. Here we change the style to `dark` and add titles to the x and y axies.
#
# **Note**
#
#   - To add spaces in text strings use `_`. They are swapped out for ` ` when the chart is generated.
#   - If you want `_`'s in your strings...TOUGH LUCK :-(
#
# `![demo](https://yamgal-server-c6l3dwv2sq-de.a.run.app/line/one:[1,2,3];two:[5,6,7]/y_title:Ooooo;x_title:Ahhhh;title:Cool_Chart;style:dark)`
#
# ![demo](https://yamgal-server-c6l3dwv2sq-de.a.run.app/line/one:[1,2,3];two:[5,6,7]/y_title:Ooooo;x_title:Ahhhh;title:Cool_Chart;style:dark)

# %% [markdown]
# ## Adding Some Mode Config
#
# To be honest all the config is basic, it's just knowing words to use. Here we change the style to `dark` and add titles to the x and y axies.
#
# **Note**
#
#   - If you add `x_labels` or `y_labels` you need to provide enough of they will just stop short.
#   - Similarly, if you add too many, I will allow you to, you chart will just look weird.
#
# `![demo](https://yamgal-server-c6l3dwv2sq-de.a.run.app/line/one:[1,2,3];two:[5,6,7]/y_title:Ooooo;x_title:Ahhhh;title:Cool_Chart;style:dark;x_labels:[this,axis,has,way,too,many,labels];y_labels:[Underscores_work_like_spaces,axis_has_too_few_but_look!,This];x_label_rotation:-30;y_label_rotation:30)
# `
#
# ![demo](https://yamgal-server-c6l3dwv2sq-de.a.run.app/line/one:[1,2,3];two:[5,6,7]/y_title:Ooooo;x_title:Ahhhh;title:Cool_Chart;style:dark;x_labels:[this,axis,has,way,too,many,labels];y_labels:[Underscores_work_like_spaces,axis_has_too_few_but_look!,This];x_label_rotation:-30;y_label_rotation:30)

# %% [markdown]
# ## Interpolation
#
#
# `![demo](https://yamgal-server-c6l3dwv2sq-de.a.run.app/line/one:[1,2,1,2,3,4,5,4,5];two:[5,6,7,7,6,5,5,6,7,7,6,5,5,6]/y_title:Ooooo;x_title:Ahhhh;title:Cool_Chart;style:dark)`
#
# ![demo](https://yamgal-server-c6l3dwv2sq-de.a.run.app/line/one:[1,2,1,2,3,4,5,4,5];two:[5,6,7,7,6,5,5,6,7,7,6,5,5,6]/y_title:Ooooo;x_title:Ahhhh;title:Cool_Chart;style:dark;interpolate:quadratic)

# %% [markdown]
# ## Fill
#
# Fill below lines to a reference.
#
# **Note**:
#
#   - We fill up or down to the reference set using the `zero` option. In this case `zero` = `3`
#
#
# `[demo](https://yamgal-server-c6l3dwv2sq-de.a.run.app/line/one:[1,2,1,2,3,4,5,4,5];two:[5,6,7,7,6,5,5,6,7,7,6,5,5,6]/y_title:Ooooo;x_title:Ahhhh;title:Cool_Chart;style:dark;interpolate:quadratic;fill:True;zero:3)`
#
# ![demo](https://yamgal-server-c6l3dwv2sq-de.a.run.app/line/one:[1,2,1,2,3,4,5,4,5];two:[5,6,7,7,6,5,5,6,7,7,6,5,5,6]/y_title:Ooooo;x_title:Ahhhh;title:Cool_Chart;style:dark;interpolate:quadratic;fill:True;zero:3)

# %% [markdown]
# ## Stacked Line
#
# Change the TYPE from bar to stackedbar...ooOOoOoOoOoooo!!!!
#
# **Note**:
#
#   - Stacked_Lines_Are_Cumulative
#
#
# `![demo](https://yamgal-server-c6l3dwv2sq-de.a.run.app/stackedline/one:[1,1,1];two:[1,1,1,1,1,1,1]/y_title:Ooooo;x_title:Ahhhh;title:Stacked_Lines_Are_Cumulative;style:dark)`
#
#
# ![demo](https://yamgal-server-c6l3dwv2sq-de.a.run.app/stackedline/one:[1,1,1];two:[1,1,1,1,1,1,1]/y_title:Ooooo;x_title:Ahhhh;title:Stacked_Lines_Are_Cumulative;style:dark)

# %% [markdown]
# ## Simple Pie Charts
#
# Simple Pie Charts take a single value for each segment. You know, like a Pie Chart...derr
#
# **Note**:
#
#   - You don't need all the numbers to add to 1.0. They are normalized when the chart is generated.
#
# `![demo](https://yamgal-server-c6l3dwv2sq-de.a.run.app/pie/one:0.1;two:0.2;three:0.3;four:0.4/style:neon;title:Pie_Chart)`
#
# ![demo](https://yamgal-server-c6l3dwv2sq-de.a.run.app/pie/one:0.1;two:0.2;three:0.3;four:0.4/style:neon;title:Pie_Chart)

# %% [markdown]
# ## Multi Series Pie Chart
#
# Multi-Series Pie Charts take a list of values per segment.
#
# **Note**:
#
#   - Same normalization rules apply as with Simple Pie Charts
#
# `![demo](https://yamgal-server-c6l3dwv2sq-de.a.run.app/pie/one:[0.05,0.05];two:[0.1,0.05,0.05];three:[0.1,0.1,0.1];four:[0.2,0.1,0.05,0.05]/style:neon;title:Pie_Chart)`
#
# ![demo](https://yamgal-server-c6l3dwv2sq-de.a.run.app/pie/one:[0.05,0.05];two:[0.1,0.05,0.05];three:[0.1,0.1,0.1];four:[0.2,0.1,0.05,0.05]/style:neon;title:Muiti_Series_Pie_Chart)

# %% [markdown]
# ## Half Pie Charts
#
# Both Mulit-Series and Simple Pie Charts support the half pie configuration option.
#
# `![demo](https://yamgal-server-c6l3dwv2sq-de.a.run.app/pie/one:[0.05,0.05];two:[0.1,0.05,0.05];three:[0.1,0.1,0.1];four:[0.2,0.1,0.05,0.05]/style:neon;title:Pie_Chart;half_pie:True)`
#
# ![demo](https://yamgal-server-c6l3dwv2sq-de.a.run.app/pie/one:[0.05,0.05];two:[0.1,0.05,0.05];three:[0.1,0.1,0.1];four:[0.2,0.1,0.05,0.05]/style:neon;title:Muiti_Series_Half_Pie_Chart;half_pie:True)

# %% [markdown]
# ## Donut Pie Charts
#
# The bad news, only Simple Pie Charts support the `inner_radius` option. Good news is you can make a `half_pie` donut though.
#
# `![demo](https://yamgal-server-c6l3dwv2sq-de.a.run.app/pie/one:[0.05,0.05];two:[0.1,0.05,0.05];three:[0.1,0.1,0.1];four:[0.2,0.1,0.05,0.05]/style:neon;title:Pie_Chart;half_pie:True;inner_radius:0.4)`
#
# ![demo](https://yamgal-server-c6l3dwv2sq-de.a.run.app/pie/one:1;two:2;three:3;four:4/style:neon;title:Pie_Chart;half_pie:True;inner_radius:0.7)

# %% [markdown]
# # Simple Bar Chart
#
# You'll figure it out, you're a smart person.
#
# `![demo](https://yamgal-server-c6l3dwv2sq-de.a.run.app/bar/one:[1,2,1,2,3,4,5,4,5];two:[5,6,7,7,6,5,5,6,7,7,6,5,5,6]/y_title:Ooooo;x_title:Ahhhh;title:Bar_Chart;style:dark)`
#
# ![demo](https://yamgal-server-c6l3dwv2sq-de.a.run.app/bar/one:[1,2,1,2,3,4,5,4,5];two:[5,6,7,7,6,5,5,6,7,7,6,5,5,6]/y_title:Ooooo;x_title:Ahhhh;title:Bar_Chart;style:dark)

# %% [markdown]
# # Stacked Bar Chart
#
# Change the `TYPE` from `bar` to `stackedbar`...also ooOOoOoOoOoooo!!!!
#
# `![demo](https://yamgal-server-c6l3dwv2sq-de.a.run.app/stackedbar/one:[1,2,1,2,3,4,5,4,5];two:[5,6,7,7,6,5,5,6,7,7,6,5,5,6]/y_title:Ooooo;x_title:Ahhhh;title:Stacked_Bar_Chart;style:dark)`
#
# ![demo](https://yamgal-server-c6l3dwv2sq-de.a.run.app/stackedbar/one:[1,2,1,2,3,4,5,4,5];two:[5,6,7,7,6,5,5,6,7,7,6,5,5,6]/y_title:Ooooo;x_title:Ahhhh;title:Stacked_Bar_Chart;style:dark)

# %% [markdown]
# ## You Get The Picture
#
# ### Limitations
#
#   - The browser tends to cache the image so changes don't show up unless you
#     clear your cache and sometimes that doesn't even work. If you update the
#     name of the file each time a change is made that works, but THER NEEDS to
#     be a better way. **Potentially a githook that adds a `?<hash-of-yaml>` to
#     the end of the imageurls in the README**
